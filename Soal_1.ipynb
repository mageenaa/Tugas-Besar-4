# %%
import numpy as np
import pandas as pd

data = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

data = data.replace(' ', np.NaN)
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
print(data.isnull().sum())
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
data['TotalCharges'] = data['TotalCharges'].fillna(0)
print(data.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
convert = {'TotalCharges' : float,
          'SeniorCitizen' : object
          }

data = data.astype(convert)
print(data.dtypes)
# Out:
# customerID           object
# gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
data.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 2  3668-QPYBK    Male             0      No         No       2          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 4  9237-HQITU  Female             0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#data['gender'] = data['gender'].cat.codes
#data['MultipleLines'] = data['MultipleLines'].cat.codes
#data['InternetService'] = data['InternetService'].cat.codes
#data['Contract'] = data['Contract'].cat.codes
#data['PaymentMethod'] = data['PaymentMethod'].cat.codes
#data

# %%
Multiplelines = pd.get_dummies(data.MultipleLines, prefix='MultipleLines')
Multiplelines
# Out:
#       MultipleLines_No  MultipleLines_No phone service  MultipleLines_Yes
# 0                    0                               1                  0
# 1                    1                               0                  0
# 2                    1                               0                  0
# 3                    0                               1                  0
# 4                    1                               0                  0
# ...                ...                             ...                ...
# 7038                 0                               0                  1
# 7039                 0                               0                  1
# 7040                 0                               1                  0
# 7041                 0                               0                  1
# 7042                 1                               0                  0
#
# [7043 rows x 3 columns]

# %%
InternetService = pd.get_dummies(data.InternetService, prefix='InternetService')
InternetService
# Out:
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No
# 0                       1                            0                   0
# 1                       1                            0                   0
# 2                       1                            0                   0
# 3                       1                            0                   0
# 4                       0                            1                   0
# ...                   ...                          ...                 ...
# 7038                    1                            0                   0
# 7039                    0                            1                   0
# 7040                    1                            0                   0
# 7041                    0                            1                   0
# 7042                    0                            1                   0
#
# [7043 rows x 3 columns]

# %%
Contract = pd.get_dummies(data.Contract, prefix='Contract')
Contract
# Out:
#       Contract_Month-to-month  Contract_One year  Contract_Two year
# 0                           1                  0                  0
# 1                           0                  1                  0
# 2                           1                  0                  0
# 3                           0                  1                  0
# 4                           1                  0                  0
# ...                       ...                ...                ...
# 7038                        0                  1                  0
# 7039                        0                  1                  0
# 7040                        1                  0                  0
# 7041                        1                  0                  0
# 7042                        0                  0                  1
#
# [7043 rows x 3 columns]

# %%
PaymentMethod = pd.get_dummies(data.PaymentMethod, prefix='Contract')
PaymentMethod
# Out:
#       Contract_Bank transfer (automatic)  Contract_Credit card (automatic)  \
# 0                                      0                                 0
# 1                                      0                                 0
# 2                                      0                                 0
# 3                                      1                                 0
# 4                                      0                                 0
# ...                                  ...                               ...
# 7038                                   0                                 0
# 7039                                   0                                 1
# 7040                                   0                                 0
# 7041                                   0                                 0
# 7042                                   1                                 0
#
#       Contract_Electronic check  Contract_Mailed check
# ...

# %%
concat = [Multiplelines, InternetService, Contract, PaymentMethod]
data1 = pd.concat([data, Multiplelines], axis=1)
data2 = pd.concat([data1, InternetService], axis=1)
data3 = pd.concat([data2, Contract], axis=1)
data_new = pd.concat([data3, PaymentMethod], axis=1)

data_new = data_new.drop(['MultipleLines', 'InternetService', 'Contract', 'PaymentMethod'], axis=1)
data_new = data_new.replace({'No': '0', 'Yes': '1'})
data_new = data_new.replace({'Male': '0', 'Female': '1'})


data_new
#data2 = pd.merge(data1,InternetService, on = 'Courses')
#data3 = pd.merge(data2,Contract, on = 'Courses')
#data_new = pd.merge(data3, PaymentMethod, on = 'Courses')
#data_new
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG      1              0       1          0       1
# 1     5575-GNVDE      0              0       0          0      34
# 2     3668-QPYBK      0              0       0          0       2
# 3     7795-CFOCW      0              0       0          0      45
# 4     9237-HQITU      1              0       0          0       2
# ...          ...    ...            ...     ...        ...     ...
# 7038  6840-RESVB      0              0       1          1      24
# 7039  2234-XADUH      1              0       1          1      72
# 7040  4801-JZAZL      1              0       1          1      11
# 7041  8361-LTMKD      0              1       1          0       4
# 7042  3186-AJIEK      0              0       0          0      66
#
#      PhoneService OnlineSecurity OnlineBackup DeviceProtection  ...  \
# 0               0              0            1                0  ...
# ...

# %%
data.boxplot('TotalCharges')
# Out:
# <AxesSubplot:>

# %%
data.boxplot('tenure')
# Out:
# <AxesSubplot:>

# %%
data.boxplot('MonthlyCharges')
# Out:
# <AxesSubplot:>
